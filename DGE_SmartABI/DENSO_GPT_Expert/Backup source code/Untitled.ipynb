# %%
list = [{'source': 'sample pdf/LNCT800SoftwareApplicationManual.pdf', 'page': '58', 'type': '1_kw', 'score': '1.381146'}, {'source': 'sample pdf/LNCT800SoftwareApplicationManual.pdf', 'page': '96', 'type': '1_kw', 'score': '1.3310574'}, {'source': 'sample pdf/LNCT800SoftwareApplicationManual.pdf', 'page': '273', 'type': '1_kw', 'score': '1.2136754'}, {'source': 'sample pdf/LNCT800SoftwareApplicationManual.pdf', 'page': '35', 'type': '1_kw', 'score': '1.0615666'}, {'source': 'sample pdf/LNCT800SoftwareApplicationManual.pdf', 'page': '96', 'type': '1_kw', 'score': '0.994453'}, {'source': 'sample pdf/LNCT800SoftwareApplicationManual.pdf', 'page': '35', 'type': '2_hb', 'score': '0.013931139'}, {'source': 'sample pdf/LNCT800SoftwareApplicationManual.pdf', 'page': '58', 'type': '2_hb', 'score': '0.012295082'}, {'source': 'sample pdf/LNCT800SoftwareApplicationManual.pdf', 'page': '96', 'type': '2_hb', 'score': '0.012096774'}, {'source': 'sample pdf/LNCT800SoftwareApplicationManual.pdf', 'page': '273', 'type': '2_hb', 'score': '0.011904762'}, {'source': 'sample pdf/LNCT800SoftwareApplicationManual.pdf', 'page': '96', 'type': '2_hb', 'score': '0.011538462'}, {'source': 'sample pdf/LNCT800SoftwareApplicationManual.pdf', 'page': '297', 'type': '3_sm', 'score': 0.7577573657035828}, {'source': 'sample pdf/LNCT800SoftwareApplicationManual.pdf', 'page': '223', 'type': '3_sm', 'score': 0.749946653842926}, {'source': 'sample pdf/LNCT800SoftwareApplicationManual.pdf', 'page': '293', 'type': '3_sm', 'score': 0.7400004267692566}, {'source': 'sample pdf/LNCT800SoftwareApplicationManual.pdf', 'page': '210', 'type': '3_sm', 'score': 0.7399457097053528}, {'source': 'sample pdf/LNCT800SoftwareApplicationManual.pdf', 'page': '8', 'type': '3_sm', 'score': 0.739899605512619}]

# %%
import pandas as pd

# %%
df = pd.DataFrame(list)

# %%
df
# Out:
#                                              source page  type        score
# 0   sample pdf/LNCT800SoftwareApplicationManual.pdf   58  1_kw     1.381146
# 1   sample pdf/LNCT800SoftwareApplicationManual.pdf   96  1_kw    1.3310574
# 2   sample pdf/LNCT800SoftwareApplicationManual.pdf  273  1_kw    1.2136754
# 3   sample pdf/LNCT800SoftwareApplicationManual.pdf   35  1_kw    1.0615666
# 4   sample pdf/LNCT800SoftwareApplicationManual.pdf   96  1_kw     0.994453
# 5   sample pdf/LNCT800SoftwareApplicationManual.pdf   35  2_hb  0.013931139
# 6   sample pdf/LNCT800SoftwareApplicationManual.pdf   58  2_hb  0.012295082
# 7   sample pdf/LNCT800SoftwareApplicationManual.pdf   96  2_hb  0.012096774
# 8   sample pdf/LNCT800SoftwareApplicationManual.pdf  273  2_hb  0.011904762
# 9   sample pdf/LNCT800SoftwareApplicationManual.pdf   96  2_hb  0.011538462
# 10  sample pdf/LNCT800SoftwareApplicationManual.pdf  297  3_sm     0.757757
# ...

# %%
df['value_count']=df.groupby(["source","page"])['score'].transform('count')
df
# Out:
#                                              source page  type        score  \
# 0   sample pdf/LNCT800SoftwareApplicationManual.pdf   58  1_kw     1.381146
# 1   sample pdf/LNCT800SoftwareApplicationManual.pdf   96  1_kw    1.3310574
# 2   sample pdf/LNCT800SoftwareApplicationManual.pdf  273  1_kw    1.2136754
# 3   sample pdf/LNCT800SoftwareApplicationManual.pdf   35  1_kw    1.0615666
# 4   sample pdf/LNCT800SoftwareApplicationManual.pdf   96  1_kw     0.994453
# 5   sample pdf/LNCT800SoftwareApplicationManual.pdf   35  2_hb  0.013931139
# 6   sample pdf/LNCT800SoftwareApplicationManual.pdf   58  2_hb  0.012295082
# 7   sample pdf/LNCT800SoftwareApplicationManual.pdf   96  2_hb  0.012096774
# 8   sample pdf/LNCT800SoftwareApplicationManual.pdf  273  2_hb  0.011904762
# 9   sample pdf/LNCT800SoftwareApplicationManual.pdf   96  2_hb  0.011538462
# 10  sample pdf/LNCT800SoftwareApplicationManual.pdf  297  3_sm     0.757757
# ...

# %%
df["score"]=df["score"].astype(float)

# %%
df['rank'] = df.sort_values('score', ascending=False).groupby("type").cumcount() + 1
df
# Out:
#                                              source page  type     score  \
# 0   sample pdf/LNCT800SoftwareApplicationManual.pdf   58  1_kw  1.381146
# 1   sample pdf/LNCT800SoftwareApplicationManual.pdf   96  1_kw  1.331057
# 2   sample pdf/LNCT800SoftwareApplicationManual.pdf  273  1_kw  1.213675
# 3   sample pdf/LNCT800SoftwareApplicationManual.pdf   35  1_kw  1.061567
# 4   sample pdf/LNCT800SoftwareApplicationManual.pdf   96  1_kw  0.994453
# 5   sample pdf/LNCT800SoftwareApplicationManual.pdf   35  2_hb  0.013931
# 6   sample pdf/LNCT800SoftwareApplicationManual.pdf   58  2_hb  0.012295
# 7   sample pdf/LNCT800SoftwareApplicationManual.pdf   96  2_hb  0.012097
# 8   sample pdf/LNCT800SoftwareApplicationManual.pdf  273  2_hb  0.011905
# 9   sample pdf/LNCT800SoftwareApplicationManual.pdf   96  2_hb  0.011538
# 10  sample pdf/LNCT800SoftwareApplicationManual.pdf  297  3_sm  0.757757
# 11  sample pdf/LNCT800SoftwareApplicationManual.pdf  223  3_sm  0.749947
# ...

# %%
df.sort_values(by= ["value_count","rank","type"], ascending=[False,True,True])
# Out:
#                                              source page  type     score  \
# 1   sample pdf/LNCT800SoftwareApplicationManual.pdf   96  1_kw  1.331057
# 7   sample pdf/LNCT800SoftwareApplicationManual.pdf   96  2_hb  0.012097
# 4   sample pdf/LNCT800SoftwareApplicationManual.pdf   96  1_kw  0.994453
# 9   sample pdf/LNCT800SoftwareApplicationManual.pdf   96  2_hb  0.011538
# 0   sample pdf/LNCT800SoftwareApplicationManual.pdf   58  1_kw  1.381146
# 5   sample pdf/LNCT800SoftwareApplicationManual.pdf   35  2_hb  0.013931
# 6   sample pdf/LNCT800SoftwareApplicationManual.pdf   58  2_hb  0.012295
# 2   sample pdf/LNCT800SoftwareApplicationManual.pdf  273  1_kw  1.213675
# 3   sample pdf/LNCT800SoftwareApplicationManual.pdf   35  1_kw  1.061567
# 8   sample pdf/LNCT800SoftwareApplicationManual.pdf  273  2_hb  0.011905
# 10  sample pdf/LNCT800SoftwareApplicationManual.pdf  297  3_sm  0.757757
# 11  sample pdf/LNCT800SoftwareApplicationManual.pdf  223  3_sm  0.749947
# ...

# %%
df.drop_duplicates(subset=["source","page"], keep= "first")
# Out:
#                                              source page  type     score  \
# 0   sample pdf/LNCT800SoftwareApplicationManual.pdf   58  1_kw  1.381146
# 1   sample pdf/LNCT800SoftwareApplicationManual.pdf   96  1_kw  1.331057
# 2   sample pdf/LNCT800SoftwareApplicationManual.pdf  273  1_kw  1.213675
# 3   sample pdf/LNCT800SoftwareApplicationManual.pdf   35  1_kw  1.061567
# 10  sample pdf/LNCT800SoftwareApplicationManual.pdf  297  3_sm  0.757757
# 11  sample pdf/LNCT800SoftwareApplicationManual.pdf  223  3_sm  0.749947
# 12  sample pdf/LNCT800SoftwareApplicationManual.pdf  293  3_sm  0.740000
# 13  sample pdf/LNCT800SoftwareApplicationManual.pdf  210  3_sm  0.739946
# 14  sample pdf/LNCT800SoftwareApplicationManual.pdf    8  3_sm  0.739900
#
#     value_count  rank
# 0             2     1
# 1             4     2
# 2             2     3
# 3             2     4
# 10            1     1
# 11            1     2
# 12            1     3
# 13            1     4
# 14            1     5

# %%
new_df = df.sort_values(by= ["value_count","rank","type"], ascending=[False,True,True]).drop_duplicates(subset=["source","page"], keep= "first")

# %%
new_df
# Out:
#                                              source page  type     score  \
# 1   sample pdf/LNCT800SoftwareApplicationManual.pdf   96  1_kw  1.331057
# 0   sample pdf/LNCT800SoftwareApplicationManual.pdf   58  1_kw  1.381146
# 5   sample pdf/LNCT800SoftwareApplicationManual.pdf   35  2_hb  0.013931
# 2   sample pdf/LNCT800SoftwareApplicationManual.pdf  273  1_kw  1.213675
# 10  sample pdf/LNCT800SoftwareApplicationManual.pdf  297  3_sm  0.757757
# 11  sample pdf/LNCT800SoftwareApplicationManual.pdf  223  3_sm  0.749947
# 12  sample pdf/LNCT800SoftwareApplicationManual.pdf  293  3_sm  0.740000
# 13  sample pdf/LNCT800SoftwareApplicationManual.pdf  210  3_sm  0.739946
# 14  sample pdf/LNCT800SoftwareApplicationManual.pdf    8  3_sm  0.739900
#
#     value_count  rank
# 1             4     2
# 0             2     1
# 5             2     1
# 2             2     3
# 10            1     1
# 11            1     2
# 12            1     3
# 13            1     4
# 14            1     5

# %%
new_df.head(4).to_dict(orient='records')
# Out:
# [{'source': 'sample pdf/LNCT800SoftwareApplicationManual.pdf',
#   'page': '96',
#   'type': '1_kw',
#   'score': 1.3310574,
#   'value_count': 4,
#   'rank': 2},
#  {'source': 'sample pdf/LNCT800SoftwareApplicationManual.pdf',
#   'page': '58',
#   'type': '1_kw',
#   'score': 1.381146,
#   'value_count': 2,
#   'rank': 1},
#  {'source': 'sample pdf/LNCT800SoftwareApplicationManual.pdf',
#   'page': '35',
#   'type': '2_hb',
#   'score': 0.013931139,
#   'value_count': 2,
#   'rank': 1},
#  {'source': 'sample pdf/LNCT800SoftwareApplicationManual.pdf',
#   'page': '273',
#   'type': '1_kw',
#   'score': 1.2136754,
#   'value_count': 2,
#   'rank': 3}]
