# %%
import pandas as pd

# %%
df = pd.read_excel("History_hutbui.xlsx")

# %%
df
# Out:
#        1, Manual:     MÁY HÚT BỤI AMANO PiF-D/SD Series – AMANO-HASON  \
# 0              NaN  https://amano.com.ph/dust-and-mist-collection-...
# 1  2, Lý lịch máy:                                                NaN
# 2              NaN                                                NaN
# 3              NaN                                            No\n 番号
# 4              NaN                                                  1
# 5              NaN                                                  2
# 6              NaN                                                  3
# 7              NaN                                                  4
# 8              NaN                                                  5
# 9              NaN                                                  6
#
#    Unnamed: 2  Unnamed: 3 Unnamed: 4    Unnamed: 5           Unnamed: 6  \
# 0         NaN         NaN        NaN           NaN                  NaN
# ...

# %%
# Out:
# array([[nan,
#         'https://amano.com.ph/dust-and-mist-collection-system-2/pif-series-2/',
#         nan, nan, nan, nan, nan, nan,
#         '(Dòng máy tương tự với máy đang sử dụng )', nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan],
#        ['2, Lý lịch máy:', nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan],
#        [nan, 'No\n 番号', 'Trạng thái', 'Số chỉ thị', 'Line ',
#         'Tên thiết bị', 'Số quản lý thiết bị', 'Loại công trình',
#         'PP bảo dưỡng', 'Vùng thao tác ', 'LK đồng bộ',
# ...
